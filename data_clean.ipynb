# %%
import pandas as pd

# %%
df = pd.read_excel("Computer Science Depersonalised EC Tracker 2020-2021(1).xlsx", sheet_name="EC Claims 20-21")
df.head(5)
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#   To be completed by the School  \
# 0        Date approved by Panel
# 1           2020-10-02 00:00:00
# 2           2020-10-06 00:00:00
# 3           2020-10-06 00:00:00
# 4           2020-10-06 00:00:00
#
#                                           Unnamed: 1  \
# 0                                            Outcome
# 1           A. Rejected - grounds are not acceptable
# 2  G. Approved - sufficient grounds to conclude a...
# 3  G. Approved - sufficient grounds to conclude a...
# 4  G. Approved - sufficient grounds to conclude a...
#
#                                           Unnamed: 2      Unnamed: 3  \
# 0  Recommendation if approved (fill in if outcome...  Extension Date
# 1                                                NaN             NaN
# ...
